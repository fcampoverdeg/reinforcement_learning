# %% [markdown]
# <div align="center" style="line-height: 1.7;">
#     <h2 style="font-weight: 600;"><strong>Results</strong></h2>
# </div>
#
# &nbsp;

# %% [markdown]
# ## 2) Research Questions
# This section aims to provide an answer to the research questions behind the
