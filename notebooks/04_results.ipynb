# %%
# --- Setup -------------------------------------------------------------------
import os, sys, json, glob
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# repo layout: /notebooks + /src
sys.path.append(os.path.abspath("../src"))

from rl_capstone import GridWorld, WorldSettings
from rl_capstone.rl_algorithms import TrainConfig
from rl_capstone.utils import evaluate_policy, greedy_policy_from_0

# If these are in rl_algorithms (recommended)
from rl_capstone.rl_algorithms import q_learning_with_logs, sarsa_with_logs, dyna_q_with_logs
try:
    from rl_capstone.rl_algorithms import prioritized_sweeping_with_logs  # optional
    HAS_PS = True
except Exception:
    HAS_PS = False

print("Imports OK.")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 15
#      12 from rl_capstone.utils import evaluate_policy, greedy_policy_from_0
#      14 # If these are in rl_algorithms (recommended)
# ---> 15 from rl_capstone.rl_algorithms import q_learning_with_logs, sarsa_with_logs, dyna_q_with_logs
#      16 try:
#      17     from rl_capstone.rl_algorithms import prioritized_sweeping_with_logs  # optional
#
# ImportError: cannot import name 'q_learning_with_logs' from 'rl_capstone.rl_algorithms' (/home/houndsito/Documents/Development/github/fcampoverdeg/reinforcement_learning/src/rl_capstone/rl_algorithms.py)
